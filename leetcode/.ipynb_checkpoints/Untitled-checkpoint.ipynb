# %%
import nbformat
import pandas as pd
import re
import os

# %%
def readSingleIpynb(nbText):
    df = pd.DataFrame()
    section = "Missing"
    for cell in nbText['worksheets'][0]['cells']:
        if cell['cell_type'] == 'heading' and cell['level'] == 1:
            section = cell['source']
        if cell['cell_type'] == 'heading' and cell['level'] == 2:
            results = re.search(r"([0-9]*)\.\s([0-9A-Za-z\s]*)", cell['source'])
            if results is not None:
                record = {"number": results.groups()[0], "name": results.groups()[1], "section":section}
            else:
                record = {"number": -1, "name": cell['source'], "section": section}
            df = df.append(record, ignore_index=True)
    return df

# %%
def readFolderIpynb():
    df = pd.DataFrame()
    for file in os.listdir("./leetcode"):
        if file.endswith('ipynb'):
            nb = nbformat.read(file, as_version=3)
            tmp = readSingleIpynb(nb)
            df = pd.concat([df, tmp], axis=0, ignore_index=True)

    df.number = df.number.astype('int32', errors='ignore')
    df = df.sort_values(by="section").reset_index(drop=True)

# %%
df
# Out:
#     number                                           name              section
# 0       46                                   Permutations         Backtracking
# 1       47                                Permutations II         Backtracking
# 2       78                                        Subsets         Backtracking
# 3      200                              Number of Islands           DFS Search
# 4       15                                           3Sum      Double Pointers
# 5       75                                    Sort Colors      Double Pointers
# 6      283                                    Move Zeroes      Double Pointers
# 7      713                   Subarray Product Less Than K      Double Pointers
# 8     2218            Maximum Value of K Coins From Piles  Dynamic Programming
# 9      377                             Combination Sum IV  Dynamic Programming
# 10     322                                    Coin Change  Dynamic Programming
# 11    1049                           Last Stone Weight II  Dynamic Programming
# 12     494                                     Target Sum  Dynamic Programming
# 13     416                     Partition Equal Subset Sum  Dynamic Programming
# 14      -1                          0-1 Knap Sack Problem  Dynamic Programming
# 15     309  Best Time to Buy and Sell Stock with Cooldown  Dynamic Programming
# 16     221                                 Maximal Square  Dynamic Programming
# 17     198                                   House Robber  Dynamic Programming
# 18     152                       Maximum Product Subarray  Dynamic Programming
# 19      64                               Minimum Path Sum  Dynamic Programming
# 20    1143                     Longest Common Subsequence  Dynamic Programming
# 21     647                         Palindromic Substrings  Dynamic Programming
# 22       5                  Longest Palindromic Substring  Dynamic Programming
# 23     279                                Perfect Squares  Dynamic Programming
# 24     128                   Longest Consecutive Sequence           Hash Table
# 25     496                         Next Greater Element I      Monotonic Stack
# 26     739                             Daily Temperatures      Monotonic Stack
# 27     239                         Sliding Window Maximum      Monotonic Stack
# 28     304                            Range Sum Query 2D            Prefix Sum
# 29     370                                 Range Addition           Prefix Sum
# 30      56                                Merge Intervals      Quick Selection
# 31     215                Kth Largest Element in an Array      Quick Selection
# 32     238                   Product of Array Except Self      Quick Selection
